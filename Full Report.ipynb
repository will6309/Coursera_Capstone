# %% [markdown]
# ## 1.Introduction/Business Problem
#
# New York City has been described as the cultural,] financial, and media capital of the world. It has a strong multicultural background.  People visit or migrate there may from anywhere in the world.  I found that food can reflect where people are from. So we would like to explore different foods in different neighborhoods by studying what kind of restaurant is the most popular in each neighborhood. This work may help people select which neighborhood they want to live just based on their tastes.

# %% [markdown]
# ## 2. Data
# #### a.Neighborhood Data.
#
# New York Neighborhood Data is needed for the information of each neighbor and for extracting the restaurant data. This dataset is downloaded from the website: https://cocl.us/new_york_dataset.
#
# #### b.Geospatial Data.
#
# The geospatial data of New York is obtained from the Foursquare API. All the information related to the coordinates and venues are obtained through this API. With this information, I can get idea of distributions of venues in different neighborhood, such as the Chinese Restaurant, Thai Restaurant and Japanese Restaurant. I have used the unsupervised learning K-means algorithm to cluster the venues.

# %% [markdown]
# ## 3.Methodology
#
# ##### a. Collecting data
# First of all, I have downloaded data of New York from https://cocl.us/new_york_dataset and open the data with json_data. Four colums have been imported.
# ![1.JPG](attachment:1.JPG)
#
# #### b. Create map of New York
# Then, I created a map of New York using latitude and longitude values and markers were added. In this step Foursquare API was used.
# ![2.JPG](attachment:2.JPG)
#
# #### c. Exploration of neighborhood
# After getting the above information, I have explored and analyzed the data by getting nearby venues,and grouping venues, rank the most popular venues.
# ![3.JPG](attachment:3.JPG)
#
# ![4.JPG](attachment:4.JPG)

# %% [markdown]
# ## 4.Results
#
# As mentioned above, we have got the most popular venues and group the neighborhoods by venues. Then we obtained the data for restaurants which give the information of what we want.
#
# ![5.JPG](attachment:5.JPG)
#
# I then visulized the data on the map.
#
# ![6.JPG](attachment:6.JPG)

# %% [markdown]
# ## 5.Discussions
#
# According to the result, we found that the Chinese restaurant is the most popular in Beechhurst,Chinatown,Concourse,East New York, etc while Japanese is more popular in Flatiron,Lindenwood. It is suggested that there maybe more Chinese an Japanese population in those neighborhood respectively.
#
# Bronxdale has more New American Restaurants, so the population maybe more Americans.

# %% [markdown]
# ## 6.Conclusions
#
# This method is good at visulizing the distribution of restaurants of different kind. It is promising in providing information for tourists and migrants. If this is combined with other information, more precise advices can be given to the people.

# %% [markdown]
# ## 7. References
#
# 1. https://en.wikipedia.org/wiki/New_York_City
# 2. https://cocl.us/new_york_dataset
# 3. www.foursquare.com
